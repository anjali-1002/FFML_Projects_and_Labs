# %% [markdown]
# <a href="https://colab.research.google.com/github/anjali-1002/FFML_Projects_and_Labs/blob/main/30FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 03:09:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   263MB/s    in 0.3s
#
# 2025-03-15 03:09:39 (263 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39160   1409.0177v2  Sparse systems are usually parameterized by a ...  stat
# 6364   1611.07308v1  We introduce the variational graph auto-encode...  stat
# 37959   1301.7118v1  Recently, many regularized procedures have bee...  stat
# 37511  1708.08113v3  We consider the problem of tracking an intrude...    cs
# 33595   1404.0695v1  Flower pollination algorithm is a new nature-i...    cs
# ...             ...                                                ...   ...
# 25324  1507.06617v4  In this paper we propose a supervised object r...    cs
# 14261  1504.01369v4  This paper is concerned with jointly recoverin...    cs
# 37188  1610.01044v1  We outline a program in the area of formalizat...    cs
# 550     1301.3605v3  Recent studies have shown that deep neural net...    cs
# 8174    1408.3337v1  Enlarged lymph nodes (LNs) can provide importa...    cs
#
#                                                    title  year  \
# 39160  Persistent Homology in Sparse Regression and I...  2014
# 6364                     Variational Graph Auto-Encoders  2016
# 37959  A note on selection stability: combining stabi...  2013
# 37511  Novel Sensor Scheduling Scheme for Intruder Tr...  2017
# 33595  Multi-objective Flower Algorithm for Optimization  2014
# ...                                                  ...   ...
# 25324  Fourier descriptors based on the structure of ...  2015
# 14261    Information Recovery from Pairwise Measurements  2015
# 37188              DeepAlgebra - an outline of a program  2016
# 550    Feature Learning in Deep Neural Networks - Stu...  2013
# 8174   2D View Aggregation for Lymph Node Detection U...  2014
#
#                                                 keywords
# 39160  [parameterized, parameter, determines, paramet...
# 6364   [introduce, variational, framework, unsupervis...
# 37959  [regularized, procedures, selection, regressio...
# 37511  [configuration, accurately, consumption, formu...
# 33595  [pollination, algorithm, algorithm, characteri...
# ...                                                  ...
# 25324  [supervised, recognition, semidiscrete, transl...
# 14261  [concerned, recovering, variables, collection,...
# 37188  [formalization, mathematics, algebraic, constr...
# 550    [significantly, vocabulary, recognition, discr...
# 8174   [important, information, diagnosis, measuring,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39160    [parameterized, parameter, determines, paramet...
# 6364     [introduce, variational, framework, unsupervis...
# 37959    [regularized, procedures, selection, regressio...
# 37511    [configuration, accurately, consumption, formu...
# 33595    [pollination, algorithm, algorithm, characteri...
#                                ...
# 32080    [algorithm, communicating, algorithm, regulari...
# 22341    [characterized, contamination, different, comb...
# 40008    [clustering, fundamental, operation, clusterin...
# 23318    [communication, understand, emotional, describ...
# 21817    [semiparametric, nonparanormal, efficiently, e...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8727 words.
# Out of those 4585 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ac1af968-b81f-4d53-8981-b6a3c27c6649" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac1af968-b81f-4d53-8981-b6a3c27c6649")) {                    Plotly.newPlot(                        "ac1af968-b81f-4d53-8981-b6a3c27c6649",                        [{"x":["parameter","parameterized","characterizing","structures","determines","morphometry","alterations","organization","exploited","additional","homological","regression","difficult","thresholding","multivariate","topological","anatomical","technique","experienced","application","introduced","dimension","persistent","fundamental","computation","competitive","interpretable","introduce","demonstrate","significantly","variables","performance","representations","naturally","structured","prediction","incorporate","predictive","convolutional","benchmark","framework","variational","unsupervised","undirected","simulation","demonstrated","therefore","consistency","generating","assumption","regularized","combining","stability","established","selection","procedures","validation","criterion","dimensionality","observable","simulations","consumption","partially","formulated","configuration","algorithm","efficient","accurately","formulate","detection","intractable","utilizing","confidence","reinforcement","intrusion","scheduling","increasing","literature","engineering","optimization","characteristics","objective","converges","functions","important","stochastic","technologies","complexity","predicting","designing","modelling","introduction","decisions","simplification","generally","analytical","approximation","recognised","strategic","abstraction","minimization","numerical","furthermore","corrupted","corruption","grassmannian","synthetic","grassmann","algorithms","subspaces","accelerate","extension","constraint","reformulate","consecutive","leveraging","experiments","constrained","clustering","efficiency","convergence","gradients","initialization","adaptively","modification","recognition","variability","recordings","simultaneously","advantage","belonging","different","equations","published","conversations","interspeech","conversation","considers","scenarios","interviews","occurrence","discriminant","supervised","considering","classifier","situation","identification","probability","classifiers","unbalanced","correlated","classification","relationships","expresses","discovery","association","extremely","measurements","measurement","filtering","perfectly","localization","compressive","undersampled","reconstruction","compressed","compression","reconstructed","properties","sufficient","correlation","generalisation","circulant","compatible","transform","knowledge","information","inference","estimation","techniques","empirically","conditions","including","regularization","graphical","challenging","estimating","microarray","replicable","sparsistent","interpretation","outperforms","dimensional","competing","dependent","essentially","procedure","guarantees","instances","factorization"],"y":[131,29,18,128,18,2,0,20,39,110,1,130,163,10,22,22,8,265,6,229,124,73,6,80,143,115,29,317,578,251,136,908,217,61,109,234,62,45,374,211,570,49,140,8,78,75,145,66,107,81,47,110,47,49,165,38,43,40,54,27,45,30,56,42,24,800,400,70,57,369,23,32,45,128,10,16,101,112,56,337,101,169,20,243,362,137,32,244,73,55,53,35,50,8,76,24,123,2,16,18,55,64,159,29,6,0,134,6,610,17,22,74,83,1,19,51,589,65,138,160,116,27,27,24,15,380,17,7,95,86,17,772,24,30,12,1,20,30,92,2,30,23,205,71,141,31,109,176,122,3,45,504,76,4,48,36,37,60,31,58,9,78,15,3,110,32,49,16,201,67,69,6,3,21,66,357,697,216,205,388,76,141,209,84,62,271,65,2,2,0,56,258,194,33,61,25,106,69,99,38],"type":"bar"},{"x":["parameter","parameterized","characterizing","structures" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4585,), (4585, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Competing</span> <span style=''>with</span> <span style=''>Dynamic</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Comparators</span> <br/><br/><span style=''>Recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>on</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developing</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>take</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observations</span> <span style=''>yet</span> <span style=''>retain</span> <span style=''>worst</span> <span style=''>case</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.5454545454545454);'>complementary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>is</span> <span style=''>to</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>perform</span> <span style=''>well</span> <span style=''>against</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.504);'>benchmarks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>these</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>together</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>fully</span> <span style=''>adaptive</span> <span style=''>method</span> <span style=''>that</span> <span style=''>competes</span> <span style=''>with</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.504);'>benchmarks</span> <span style=''>in</span> <span style=''>which</span> <span style=''>regret</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>scales</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>comparators</span> <span style=''>Notably</span> <span style=''>the</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>adapts</span> <span style=''>to</span> <span style=''>the</span> <span style=''>smaller</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>measure</span> <span style=''>in</span> <span style=''>the</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.7232704402515723);'>environment</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>our</span> <span style=''>results</span> <span style=''>to</span> <span style=''>drifting</span> <span style=''>zero</span> <span style=''>sum</span> <span style=''>two</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conformal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Explore</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functional</span> <span style=''>Data</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>applies</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conformal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>bands</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>trees</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>These</span> <span style=''>tools</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>outliers</span> <span style=''>and</span> <span style=''>clusters</span> <span style=''>Both</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>bands</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>trees</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>sets</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>process</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guaranteed</span> <span style=''>finite</span> <span style=''>sample</span> <span style=''>behavior</span> <span style=''>under</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>sets</span> <span style=''>are</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>informative</span> <span style=''>in</span> <span style=''>that</span> <span style=''>they</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style=''>the</span> <span style=''>high</span> <span style=''>density</span> <span style=''>region</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>process</span> <span style=''>While</span> <span style=''>ordinary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conformal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>has</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>we</span> <span style=''>use</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inductive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conformal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>together</span> <span style=''>with</span> <span style=''>several</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style=''>with</span> <span style=''>Billions</span> <span style=''>of</span> <span style=''>Inducing</span> <span style=''>Inputs</span> <span style=''>via</span> <span style=''>Tensor</span> <span style=''>Train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>(TT</span> <span style=''>GP)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>(GP)</span> <span style=''>models</span> <span style=''>We</span> <span style=''>build</span> <span style=''>on</span> <span style=''>previous</span> <span style=''>scalable</span> <span style=''>GP</span> <span style=''>research</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(255, 0, 0, 0.315);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.5739130434782609);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>based</span> <span style=''>on</span> <span style=''>inducing</span> <span style=''>inputs</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style=''>algebra</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>is</span> <span style=''>to</span> <span style=''>use</span> <span style=''>Tensor</span> <span style=''>Train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5739130434782609);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>train</span> <span style=''>GPs</span> <span style=''>with</span> <span style=''>billions</span> <span style=''>of</span> <span style=''>inducing</span> <span style=''>inputs</span> <span style=''>and</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>on</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.504);'>benchmarks</span> <span style=''>Further</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>training</span> <span style=''>kernels</span> <span style=''>based</span> <span style=''>on</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>without</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modifications</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>GP</span> <span style=''>model</span> <span style=''>A</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>learns</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>for</span> <span style=''>the</span> <span style=''>data</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>External</span> <span style=''>Validity</span> <span style=''>From</span> <span style=''>Do</span> <span style=''>Calculus</span> <span style=''>to</span> <span style=''>Transportability</span> <span style=''>Across</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Populations</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizability</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>findings</span> <span style=''>to</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>settings</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>populations</span> <span style=''>often</span> <span style=''>called</span> <span style=''>external</span> <span style=''>validity</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>in</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explorations</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>treats</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizability</span> <span style=''>called</span> <span style=''>transportability</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>a</span> <span style=''>license</span> <span style=''>to</span> <span style=''>transfer</span> <span style=''>causal</span> <span style=''>effects</span> <span style=''>learned</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>studies</span> <span style=''>to</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>in</span> <span style=''>which</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>studies</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conducted</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>formal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>diagrams</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>about</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>commonalities</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>populations</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>and</span> <span style=''>using</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>we</span> <span style=''>reduce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>of</span> <span style=''>transportability</span> <span style=''>to</span> <span style=''>symbolic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivations</span> <span style=''>in</span> <span style=''>the</span> <span style=''>do</span> <span style=''>calculus</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>yields</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12788184438040345)
# 	architecture (0.08357348703170028)
# 	segmentation (0.06988472622478387)
# 	knowledge (0.12860230547550433)
# 	experimental (0.14265129682997119)
# 	information (0.2510806916426513)
# 	detection (0.1329250720461095)
# 	convolutional (0.13472622478386168)
# 	recognition (0.13688760806916425)
# 	different (0.2780979827089337)
#
# Some Statistics words are:
# 	stochastic (0.1299407114624506)
# 	variables (0.13438735177865613)
# 	algorithm (0.37648221343873517)
# 	statistical (0.14723320158102768)
# 	estimation (0.17045454545454544)
# 	theoretical (0.15266798418972333)
# 	distribution (0.1842885375494071)
# 	inference (0.19219367588932806)
# 	regression (0.1724308300395257)
# 	dimensional (0.1956521739130435)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90a925a4-7371-4fa6-be3f-6266280cfe6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90a925a4-7371-4fa6-be3f-6266280cfe6f")) {                    Plotly.newPlot(                        "90a925a4-7371-4fa6-be3f-6266280cfe6f",                        [{"x":["parameter","parameterized","characterizing","structures","determines","morphometry","alterations","organization","exploited","additional","homological","regression","difficult","thresholding","multivariate","topological","anatomical","technique","experienced","application","introduced","dimension","persistent","fundamental","computation","competitive","interpretable","introduce","demonstrate","significantly","variables","performance","representations","naturally","structured","prediction","incorporate","predictive","convolutional","benchmark","framework","variational","unsupervised","undirected","simulation","demonstrated","therefore","consistency","generating","assumption","regularized","combining","stability","established","selection","procedures","validation","criterion","dimensionality","observable","simulations","consumption","partially","formulated","configuration","algorithm","efficient","accurately","formulate","detection","intractable","utilizing","confidence","reinforcement","intrusion","scheduling","increasing","literature","engineering","optimization","characteristics","objective","converges","functions","important","stochastic","technologies","complexity","predicting","designing","modelling","introduction","decisions","simplification","generally","analytical","approximation","recognised","strategic","abstraction","minimization","numerical","furthermore","corrupted","corruption","grassmannian","synthetic","grassmann","algorithms","subspaces","accelerate","extension","constraint","reformulate","consecutive","leveraging","experiments","constrained","clustering","efficiency","convergence","gradients","initialization","adaptively","modification","recognition","variability","recordings","simultaneously","advantage","belonging","different","equations","published","conversations","interspeech","conversation","considers","scenarios","interviews","occurrence","discriminant","supervised","considering","classifier","situation","identification","probability","classifiers","unbalanced","correlated","classification","relationships","expresses","discovery","association","extremely","measurements","measurement","filtering","perfectly","localization","compressive","undersampled","reconstruction","compressed","compression","reconstructed","properties","sufficient","correlation","generalisation","circulant","compatible","transform","knowledge","information","inference","estimation","techniques","empirically","conditions","including","regularization","graphical","challenging","estimating","microarray","replicable","sparsistent","interpretation","outperforms","dimensional","competing","dependent","essentially","procedure","guarantees","instances","factorization","exponentially","selecting","convexity","objectives","assumptions","initialize","importantly","bioinformatics","compromise","particularly","theoretically","extracting","sequences","visualization","ubiquitous","healthcare","arbitrary","difficulty","extraction","experimentation","distribution","intricate","increases","constrain","intrinsic","complement","satisfaction","interplay","continuous","everywhere","constraints","decomposition","following","construct","incorporating","illustrates","parameters","connected","determine","candidate","propagation","determined","initialized","recurrent","answering","individual","benchmarks","predefined","questions","available","allocation","components","computationally","involving","pe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	alterations
# 	grassmannian
# 	sparsistent
# 	allocations
# 	interventional
# 	checkable
# 	scheduled
# 	exponents
# 	transformative
# 	missforest
# 	sinusoidal
# 	tibshirani
# 	robustification
# 	marginally
# 	ultrahigh
# 	thermodynamics
# 	nonparanormal
# 	debiasing
# 	nomination
# 	discriminants
# Some words which never appear in Statistics papers:
# 	technologies
# 	oscillator
# 	adjustable
# 	additively
# 	presentations
# 	commonsense
# 	interruption
# 	personnel
# 	declarative
# 	multiphase
# 	societies
# 	participants
# 	sustainable
# 	sustainability
# 	learninginference
# 	constancy
# 	vulnerabilities
# 	photometric
# 	occlusions
# 	dominating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.091667954861648e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
